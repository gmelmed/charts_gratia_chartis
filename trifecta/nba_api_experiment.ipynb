# %%
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
import time
import config

# %%
pip install nfl_data_py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nfl_data_py as nfl
import pandas as pd

# Import team descriptive information
teams = nfl.import_team_desc()

# The 'teams' DataFrame will contain various columns related to NFL teams,
# including unique identifiers. Common ID columns you might find are:
# - 'team_id': A unique identifier for the team.
# - 'team_abbr': The common abbreviation for the team (e.g., 'BUF', 'NE').
# - 'team_name': The full name of the team (e.g., 'Buffalo Bills', 'New England Patriots').

# To view the available columns and the first few rows of the data:
print(teams.head())

# To specifically extract a list of team IDs:
team_ids = teams['team_id'].tolist()
print("\nList of NFL Team IDs:")
print(team_ids)

# save team names and ids to json
teams[['team_id', 'team_name']].to_json('data/nfl_teams.json', orient='records', indent=4)
# Out:
#   team_abbr          team_name  team_id  team_nick team_conf team_division
# 0       ARI  Arizona Cardinals     3800  Cardinals       NFC      NFC West  \
# 1       ATL    Atlanta Falcons      200    Falcons       NFC     NFC South
# 2       BAL   Baltimore Ravens      325     Ravens       AFC     AFC North
# 3       BUF      Buffalo Bills      610      Bills       AFC      AFC East
# 4       CAR  Carolina Panthers      750   Panthers       NFC     NFC South
#
#   team_color team_color2 team_color3 team_color4
# 0    #97233F     #000000     #ffb612     #a5acaf  \
# 1    #A71930     #000000     #a5acaf     #a30d2d
# 2    #241773     #9E7C0C     #9e7c0c     #c60c30
# 3    #00338D     #C60C30     #0c2e82     #d50a0a
# 4    #0085CA     #000000     #bfc0bf     #0085ca
#
#                                  team_logo_wikipedia
# 0  https://upload.wikimedia.org/wikipedia/en/thum...  \
# 1  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
url = "https://raw.githubusercontent.com/djblechn-su/nba-player-team-ids/refs/heads/master/NBA_Team_IDs.csv"

# depulicate by "NBA_Current_Link_ID"
teams = pd.read_csv(url).drop_duplicates(subset=["NBA_Current_Link_ID"])

teams = teams[['BBRef_Team_Name', 'NBA_Current_Link_ID']]

teams.to_json('data/nba_teams.json', orient='records', indent=4)

# %%
from nba_api.stats.endpoints import teaminfocommon

# Get all teams.
teams_df = teaminfocommon.TeamInfoCommon(
    # all teams
    team_id=0
    ).get_data_frames()[0]

teams_df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 4
#       1 from nba_api.stats.endpoints import teaminfocommon
#       3 # Get all teams.
# ----> 4 teams_df = teaminfocommon.TeamInfoCommon(
#       5     # all teams
#       6     team_id=0
#       7     ).get_data_frames()[0]
#       9 teams_df
#
# File ~/git_repos/charts_gratia_chartis/venv/lib/python3.12/site-packages/nba_api/stats/endpoints/teaminfocommon.py:74, in TeamInfoCommon.__init__(self, team_id, league_id, season_nullable, season_type_nullable, proxy, headers, timeout, get_request)
#      67 self.parameters = {
#      68     "TeamID": team_id,
#      69     "LeagueID": league_id,
#      70     "Season": season_nullable,
#      71     "SeasonType": season_type_nullable,
#      72 }
#      73 if get_request:
# ---> 74     self.get_request()
#
# ...

# %%
import statsapi

# %%
# Get all MLB teams and their IDs
mlb_teams = statsapi.get('teams', {'sportIds': 1})['teams']

# Extract team names and IDs
team_data = [{'team_id': team['id'], 'team_name': team['name']} for team in mlb_teams]

# Convert to DataFrame
mlb_teams_df = pd.DataFrame(team_data)

# write to json
mlb_teams_df.to_json('data/mlb_teams.json', orient='records', indent=4)

# %%
pip install nhlpy
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for nhlpy: filename=nhlpy-0.3.0-py3-none-any.whl size=4645 sha256=94f798dd5705b013fdd792e1fc5a3b40ad1e405f0195a72ece1b0a33a3b0fb6b
#   Stored in directory: /Users/gabrielmelmed/Library/Caches/pip/wheels/76/dc/ef/a3c51291bcf2c2be27689fbb7d23d78cb23e79a151470a7281
# Successfully built nhlpy
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nhlpy

# %%
from nhlpy import NHLClient

client = NHLClient()

# Get all current teams
teams = client.teams.teams()

# %%
teams_df = pd.DataFrame(teams)
teams_df = teams_df[['name', 'franchise_id']]

teams_df.to_json('data/nhl_teams.json', orient='records', indent=4)

# %%
import pandas as pd

path = '/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/mlb/mlb_ny_new_york_yankees_games.csv'

df = pd.read_csv(path)

df
# Out:
#       game_id         game_datetime   game_date game_type status  \
# 0        3497  2000-04-04T02:35:00Z  2000-04-03         R  Final
# 1        3292  2000-04-05T02:05:00Z  2000-04-04         R  Final
# 2        4975  2000-04-06T02:05:00Z  2000-04-05         R  Final
# 3        5024  2000-04-08T02:05:00Z  2000-04-07         R  Final
# 4        3415  2000-04-08T20:05:00Z  2000-04-08         R  Final
# ...       ...                   ...         ...       ...    ...
# 5001   813065  2025-10-03T00:08:00Z  2025-10-02         F  Final
# 5002   813063  2025-10-04T20:08:00Z  2025-10-04         D  Final
# 5003   813062  2025-10-05T20:08:00Z  2025-10-05         D  Final
# 5004   813061  2025-10-08T00:08:00Z  2025-10-07         D  Final
# 5005   813060  2025-10-08T23:08:00Z  2025-10-08         D  Final
#
#               away_name          home_name  away_id  home_id doubleheader  \
# 0      New York Yankees     Anaheim Angels      147      108            N
# ...

# %%
# get value counts for `game_type`
df['game_type'].value_counts()
# Out:
# R    4239
# S     562
# D      86
# L      67
# W      29
# E      14
# F       9
# Name: game_type, dtype: int64

# %%
df[df['game_type'] == 'E']
# Out:
#       game_id         game_datetime   game_date game_type status  \
# 723    243298  2004-03-28T10:00:00Z  2004-03-28         E  Final
# 724    243313  2004-03-29T03:00:00Z  2004-03-28         E  Final
# 725    243313  2004-03-29T03:00:00Z  2004-03-29         E  Final
# 728    243401  2004-04-04T17:15:00Z  2004-04-04         E  Final
# 1499   237489  2008-03-18T19:00:00Z  2008-03-18         E  Final
# 1681   257312  2009-03-03T18:15:00Z  2009-03-03         E  Final
# 1683   257335  2009-03-05T18:15:00Z  2009-03-05         E  Final
# 1926   279129  2010-04-03T17:05:00Z  2010-04-03         E  Final
# 2307   332096  2012-03-02T18:05:00Z  2012-03-02         E  Final
# 2519   363135  2013-03-06T18:05:00Z  2013-03-06         E  Final
# 2542   365671  2013-03-30T18:00:00Z  2013-03-30         E  Final
# 3309   509825  2017-03-08T18:05:00Z  2017-03-08         E  Final
# 4628   766493  2024-03-24T20:00:00Z  2024-03-24         E  Final
# ...

# %%
# get the names of the files in /Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nfl
import os
files = os.listdir('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nfl')
files
# Out:
# ['nfl_seattle_seattle_seahawks_games.csv',
#  'nfl_cleveland_cleveland_browns_games.csv',
#  'nfl_tennessee_tennessee_titans_games.csv',
#  'nfl_bay_oakland_raiders_games.csv',
#  'nfl_la_los_angeles_rams_games.csv',
#  'nfl_north_carolina_carolina_panthers_games.csv',
#  'nfl_ny_new_york_jets_games.csv',
#  'nfl_detroit_detroit_lions_games.csv',
#  'nfl_boston_new_england_patriots_games.csv',
#  'nfl_dallas_dallas_cowboys_games.csv',
#  'nfl_atlanta_atlanta_falcons_games.csv',
#  'nfl_la_los_angeles_chargers_games.csv',
#  'nfl_denver_denver_broncos_games.csv',
#  'nfl_stl_st._louis_rams_games.csv',
#  'nfl_pittsburgh_pittsburgh_steelers_games.csv',
#  'nfl_miami_miami_dolphins_games.csv',
#  'nfl_phoenix_arizona_cardinals_games.csv',
#  'nfl_ny_new_york_giants_games.csv',
#  'nfl_minneapolis_minnesota_vikings_games.csv',
#  'nfl_houston_houston_texans_games.csv',
#  'nfl_philadelphia_philadelphia_eagles_games.csv',
#  'nfl_chicago_chicago_bears_games.csv',
# ...

# %%
files = os.listdir('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nba')

for file in files:
    # replace every between the last "_" and ".csv" with "games"
    new_file = file.rsplit('_', 1)[0] + '_games.csv'
    os.rename(os.path.join('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nba', file),
              os.path.join('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nba', new_file))

# %%
# read in trifecta/data/markets_teams.json
import json
with open('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/markets_teams.json') as f:
    markets_teams = json.load(f)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 markets = []
#       3 for market in markets_teams:
# ----> 4     market_name = market['market'].lower()
#       5     markets.append(market_name)
#       8 markets
#
# TypeError: string indices must be integers, not 'str'

# %%
files = os.listdir('/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nfl')

for file in files:
    # replace

# %%
os.chdir('/Users/gabrielmelmed/git_repos/charts_gratia_chartis')

# %%
df.columns
# Out:
# Index(['game_id', 'game_datetime', 'game_date', 'game_type', 'status',
#        'away_name', 'home_name', 'away_id', 'home_id', 'doubleheader',
#        'game_num', 'home_probable_pitcher', 'away_probable_pitcher',
#        'home_pitcher_note', 'away_pitcher_note', 'away_score', 'home_score',
#        'current_inning', 'inning_state', 'venue_id', 'venue_name',
#        'national_broadcasts', 'series_status', 'winning_team', 'losing_team',
#        'winning_pitcher', 'losing_pitcher', 'save_pitcher', 'summary',
#        'SEASON', 'losing_Team'],
#       dtype='object')

# %%
df['winning_team'].sample(100)
# Out:
# 3303          Tampa Bay Rays
# 1329    Tampa Bay Devil Rays
# 1986          Tampa Bay Rays
# 1426          Tampa Bay Rays
# 255           Montreal Expos
#                 ...
# 2421          Tampa Bay Rays
# 4481          Boston Red Sox
# 3790          Tampa Bay Rays
# 546            Texas Rangers
# 3951    Washington Nationals
# Name: winning_team, Length: 100, dtype: object

# %%
df = pd.read_csv('trifecta/data/raw/mlb/mlb_tampa_rays_games.csv')

df = df[['game_date', 'game_type', 'winning_team', 'losing_team']] 

df
# Out:
#        game_date game_type          winning_team           losing_team
# 0     2000-04-03         R  Tampa Bay Devil Rays       Minnesota Twins
# 1     2000-04-04         R       Minnesota Twins  Tampa Bay Devil Rays
# 2     2000-04-05         R       Minnesota Twins  Tampa Bay Devil Rays
# 3     2000-04-06         R  Tampa Bay Devil Rays       Minnesota Twins
# 4     2000-04-07         R     Cleveland Indians  Tampa Bay Devil Rays
# ...          ...       ...                   ...                   ...
# 4781  2025-09-24         R        Tampa Bay Rays     Baltimore Orioles
# 4782  2025-09-25         R     Baltimore Orioles        Tampa Bay Rays
# 4783  2025-09-26         R     Toronto Blue Jays        Tampa Bay Rays
# 4784  2025-09-27         R     Toronto Blue Jays        Tampa Bay Rays
# 4785  2025-09-28         R     Toronto Blue Jays        Tampa Bay Rays
#
# [4786 rows x 4 columns]

# %%
df['winning_team'] = df['winning_team'].str.replace('Tampa Bay Devil Rays', 'Tampa Bay Rays', regex=False)
df['losing_team'] = df['losing_team'].str.replace('Tampa Bay Devil Rays', 'Tampa Bay Rays', regex=False)

df
# Out:
#        game_date game_type       winning_team        losing_team
# 0     2000-04-03         R     Tampa Bay Rays    Minnesota Twins
# 1     2000-04-04         R    Minnesota Twins     Tampa Bay Rays
# 2     2000-04-05         R    Minnesota Twins     Tampa Bay Rays
# 3     2000-04-06         R     Tampa Bay Rays    Minnesota Twins
# 4     2000-04-07         R  Cleveland Indians     Tampa Bay Rays
# ...          ...       ...                ...                ...
# 4781  2025-09-24         R     Tampa Bay Rays  Baltimore Orioles
# 4782  2025-09-25         R  Baltimore Orioles     Tampa Bay Rays
# 4783  2025-09-26         R  Toronto Blue Jays     Tampa Bay Rays
# 4784  2025-09-27         R  Toronto Blue Jays     Tampa Bay Rays
# 4785  2025-09-28         R  Toronto Blue Jays     Tampa Bay Rays
#
# [4786 rows x 4 columns]

# %%
# drop rows where game_type is "E" or "S"
df = df[~df['game_type'].isin(['E', 'S'])]

# %%
df['game_date'] = pd.to_datetime(df['game_date'])

df
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_55941/1141866280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['game_date'] = pd.to_datetime(df['game_date'])
#       game_date game_type       winning_team        losing_team
# 0    2000-04-03         R     Tampa Bay Rays    Minnesota Twins
# 1    2000-04-04         R    Minnesota Twins     Tampa Bay Rays
# 2    2000-04-05         R    Minnesota Twins     Tampa Bay Rays
# 3    2000-04-06         R     Tampa Bay Rays    Minnesota Twins
# 4    2000-04-07         R  Cleveland Indians     Tampa Bay Rays
# ...         ...       ...                ...                ...
# 4781 2025-09-24         R     Tampa Bay Rays  Baltimore Orioles
# ...

# %%
import json
from pathlib import Path

# Get the current working directory (already set to charts_gratia_chartis in cell 19)
script_dir = Path.cwd()

# Load markets_teams.json
with open(script_dir / "trifecta" / "data" / "markets_teams.json") as f:
    markets_data = json.load(f)

# %%
from anyio import Path
import pandas as pd
import os
import sys
from pathlib import Path


mlb_teams = []
for market in markets_data['markets_teams']:
    for team in market['teams']:
        if team['league'] == 'MLB':
            mlb_teams.append({
                'market': market['market'],
                'name': team['name'].replace(' ', '_').lower(),
                'api_id': team['api_id'],
                'abbr': team['abbr'],
                'full_name': team['full_name']
            })

def clean_mlb_data(df):
    """Clean MLB data."""
    # Select relevant columns
    df = df[['game_date', 'game_type', 'winning_team', 'losing_team']].copy()

    # Standardize team names
    df['winning_team'] = df['winning_team'].str.replace('Tampa Bay Devil Rays', 'Tampa Bay Rays', regex=False)
    df['losing_team'] = df['losing_team'].str.replace('Tampa Bay Devil Rays', 'Tampa Bay Rays', regex=False)
    df['winning_team'] = df['winning_team'].str.replace('Florida Marlins', 'Miami Marlins', regex=False)
    df['losing_team'] = df['losing_team'].str.replace('Florida Marlins', 'Miami Marlins', regex=False)
    df['winning_team'] = df['winning_team'].str.replace('Cleveland Indians', 'Cleveland Guardians', regex=False)
    df['losing_team'] = df['losing_team'].str.replace('Cleveland Indians', 'Cleveland Guardians', regex=False) 
    
    # Drop exhibition and spring training games
    df = df[~df['game_type'].isin(['E', 'S'])]
    
    # Convert game_date to datetime
    df['game_date'] = pd.to_datetime(df['game_date'])
    # rename game_date to date
    df = df.rename(columns={'game_date': 'date'})
    
    return df



for i in mlb_teams:
    market = i['market'].lower()
    team_name = i['name'].lower()
    team_abbr = i['abbr']
    team_full_name = i['full_name']

    input_file = script_dir.parent / "charts_gratia_chartis" / "trifecta" / "data" / "raw" / "mlb" / f"mlb_{market}_{team_name}_games.csv"
    print(f"\n{'='*60}")
    print(f"Processing data for {team_full_name}")
    if not input_file.exists():
        print(f"Input file {input_file} does not exist. Skipping.")
        continue
    
    df = pd.read_csv(input_file)
    df_cleaned = clean_mlb_data(df)
# Out:
# ...
# Processing data for New York Yankees
#
# ...
# Processing data for New York Mets
#
# ...
# Processing data for Los Angeles Dodgers
#
# ...
# Processing data for Chicago White Sox
#
# ...
# Processing data for Chicago Cubs
#
# ...
# Processing data for Texas Rangers
#
# ...
# Processing data for Oakland Athletics
#
# ...
# Processing data for San Francisco Giants
#
# ...
# Processing data for Washington Nationals
#
# ...
# Processing data for Boston Red Sox
#
# ...
# Processing data for Philadelphia Phillies
#
# ...
# Processing data for Miami Marlins
#
# ...
# Processing data for Atlanta Braves
#
# ...
# Processing data for Detroit Tigers
#
# ...
# Processing data for Cleveland Guardians
#
# ...
# Processing data for Pittsburgh Pirates
#
# ...
# Processing data for Minnesota Twins
#
# ...
# Processing data for Milwaukee Brewers
#
# ...
# Processing data for St. Louis Cardinals
#
# ...
# Processing data for Tampa Bay Rays
#
# ...
# Processing data for Colorado Rockies
#
# ...
# Processing data for Seattle Mariners
#
# ...
# Processing data for Houston Astros
#
# ...
# Processing data for Arizona Diamondbacks
#
# ...

# %%
df = pd.read_csv("trifecta/data/raw/mlb/mlb_ny_yankees_games.csv")

df = clean_mlb_data(df)

# %%
df
# Out:
#            date game_type       winning_team        losing_team
# 0    2000-04-03         R   New York Yankees     Anaheim Angels
# 1    2000-04-04         R   New York Yankees     Anaheim Angels
# 2    2000-04-05         R     Anaheim Angels   New York Yankees
# 3    2000-04-07         R   Seattle Mariners   New York Yankees
# 4    2000-04-08         R   New York Yankees   Seattle Mariners
# ...         ...       ...                ...                ...
# 5001 2025-10-02         F   New York Yankees     Boston Red Sox
# 5002 2025-10-04         D  Toronto Blue Jays   New York Yankees
# 5003 2025-10-05         D  Toronto Blue Jays   New York Yankees
# 5004 2025-10-07         D   New York Yankees  Toronto Blue Jays
# 5005 2025-10-08         D  Toronto Blue Jays   New York Yankees
#
# [4430 rows x 4 columns]

# %%
df['yankees_win'] = (df['winning_team'] == 'New York Yankees').astype(int)

# %%
ny_wins = df[['date', 'yankees_win']]

ny_wins
# Out:
#            date  yankees_win
# 0    2000-04-03            1
# 1    2000-04-04            1
# 2    2000-04-05            0
# 3    2000-04-07            0
# 4    2000-04-08            1
# ...         ...          ...
# 5001 2025-10-02            1
# 5002 2025-10-04            0
# 5003 2025-10-05            0
# 5004 2025-10-07            1
# 5005 2025-10-08            0
#
# [4430 rows x 2 columns]

# %%
df = pd.read_csv("/Users/gabrielmelmed/git_repos/charts_gratia_chartis/trifecta/data/raw/nhl/nhl_bay_sharks_games.csv")

df
# Out:
#        game_date home_team_abbr away_team_abbr  home_score  away_score  \
# 0     2000-10-06            SJS            STL         1.0         4.0
# 1     2000-10-12            SJS            PHX         2.0         1.0
# 2     2000-10-14            SJS            BOS         5.0         2.0
# 3     2000-10-18            DAL            SJS         2.0         1.0
# 4     2000-10-20            MIN            SJS         1.0         3.0
# ...          ...            ...            ...         ...         ...
# 2288  2026-04-09            ANA            SJS         NaN         NaN
# 2289  2026-04-11            SJS            VAN         NaN         NaN
# 2290  2026-04-13            NSH            SJS         NaN         NaN
# 2291  2026-04-15            CHI            SJS         NaN         NaN
# 2292  2026-04-16            WPG            SJS         NaN         NaN
#
#         SEASON
# 0     20002001
# 1     20002001
# 2     20002001
# 3     20002001
# 4     20002001
# ...        ...
# ...

# %%
# drop rows where home_score or away_score is NaN
df = df.dropna(subset=['home_score', 'away_score'])

df
# Out:
#        game_date home_team_abbr away_team_abbr  home_score  away_score  \
# 0     2000-10-06            SJS            STL         1.0         4.0
# 1     2000-10-12            SJS            PHX         2.0         1.0
# 2     2000-10-14            SJS            BOS         5.0         2.0
# 3     2000-10-18            DAL            SJS         2.0         1.0
# 4     2000-10-20            MIN            SJS         1.0         3.0
# ...          ...            ...            ...         ...         ...
# 2237  2025-12-01            SJS            UTA         6.0         3.0
# 2238  2025-12-03            SJS            WSH         1.0         7.0
# 2239  2025-12-05            DAL            SJS         4.0         1.0
# 2240  2025-12-07            CAR            SJS         1.0         4.0
# 2241  2025-12-09            PHI            SJS         4.0         1.0
#
#         SEASON
# 0     20002001
# 1     20002001
# 2     20002001
# 3     20002001
# 4     20002001
# ...        ...
# ...

# %%
df.columns
# Out:
# Index(['game_date', 'home_team_abbr', 'away_team_abbr', 'home_score',
#        'away_score', 'SEASON'],
#       dtype='object')

# %%
# make a winner column based on home_score and away_score

df['winning_team'] = df.apply(lambda row: row['home_team_abbr'] if row['home_score'] > row['away_score'] else row['away_team_abbr'], axis=1)

df = df.rename(columns={'game_date': 'date'})
df['date'] = pd.to_datetime(df['date'])

df
# Out:
#            date home_team_abbr away_team_abbr  home_score  away_score  \
# 0    2000-10-06            SJS            STL         1.0         4.0
# 1    2000-10-12            SJS            PHX         2.0         1.0
# 2    2000-10-14            SJS            BOS         5.0         2.0
# 3    2000-10-18            DAL            SJS         2.0         1.0
# 4    2000-10-20            MIN            SJS         1.0         3.0
# ...         ...            ...            ...         ...         ...
# 2237 2025-12-01            SJS            UTA         6.0         3.0
# 2238 2025-12-03            SJS            WSH         1.0         7.0
# 2239 2025-12-05            DAL            SJS         4.0         1.0
# 2240 2025-12-07            CAR            SJS         1.0         4.0
# 2241 2025-12-09            PHI            SJS         4.0         1.0
#
#         SEASON winning_team
# 0     20002001          STL
# 1     20002001          SJS
# 2     20002001          SJS
# ...

# %%
df = pd.read_csv("trifecta/data/raw/nfl/nfl_bay_raiders_games.csv")

df = df[['gameday','game_type','home_team', 'away_team', 'home_score', 'away_score']]

df['winning_team'] = df.apply(lambda row: row['home_team'] if row['home_score'] > row['away_score'] else row['away_team'], axis=1)

df
# Out:
#         gameday game_type home_team away_team  home_score  away_score
# 0    2000-09-03       REG       OAK        SD         9.0         6.0
# 1    2000-09-10       REG       IND       OAK        31.0        38.0
# 2    2000-09-17       REG       OAK       DEN        24.0        33.0
# 3    2000-09-24       REG       OAK       CLE        36.0        10.0
# 4    2000-10-08       REG        SF       OAK        28.0        34.0
# ..          ...       ...       ...       ...         ...         ...
# 323  2019-12-01       REG        KC       OAK        40.0         9.0
# 324  2019-12-08       REG       OAK       TEN        21.0        42.0
# 325  2019-12-15       REG       OAK       JAX        16.0        20.0
# 326  2019-12-22       REG       LAC       OAK        17.0        24.0
# 327  2019-12-29       REG       DEN       OAK        16.0        15.0
#
# [328 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'gameday', 'weekday',
#        'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
#        'location', 'result', 'total', 'overtime', 'old_game_id', 'gsis',
#        'nfl_detail_id', 'pfr', 'pff', 'espn', 'ftn', 'away_rest', 'home_rest',
#        'away_moneyline', 'home_moneyline', 'spread_line', 'away_spread_odds',
#        'home_spread_odds', 'total_line', 'under_odds', 'over_odds', 'div_game',
#        'roof', 'surface', 'temp', 'wind', 'away_qb_id', 'home_qb_id',
#        'away_qb_name', 'home_qb_name', 'away_coach', 'home_coach', 'referee',
#        'stadium_id', 'stadium'],
#       dtype='object')

# %%
df[['gameday','game_type','home_team', 'away_team', 'home_score', 'away_score']]
# Out:
#         gameday game_type home_team away_team  home_score  away_score
# 0    2000-09-03       REG       OAK        SD         9.0         6.0
# 1    2000-09-10       REG       IND       OAK        31.0        38.0
# 2    2000-09-17       REG       OAK       DEN        24.0        33.0
# 3    2000-09-24       REG       OAK       CLE        36.0        10.0
# 4    2000-10-08       REG        SF       OAK        28.0        34.0
# ..          ...       ...       ...       ...         ...         ...
# 323  2019-12-01       REG        KC       OAK        40.0         9.0
# 324  2019-12-08       REG       OAK       TEN        21.0        42.0
# 325  2019-12-15       REG       OAK       JAX        16.0        20.0
# 326  2019-12-22       REG       LAC       OAK        17.0        24.0
# 327  2019-12-29       REG       DEN       OAK        16.0        15.0
#
# [328 rows x 6 columns]

# %%
df['game_type'].value_counts()
# Out:
# REG    320
# DIV      3
# CON      2
# WC       2
# SB       1
# Name: game_type, dtype: int64
