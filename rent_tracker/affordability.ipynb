# %%
import pandas as pd

# %%
url = "https://files.zillowstatic.com/research/public_csvs/new_renter_affordability/Metro_new_renter_affordability_uc_sfrcondomfr_sm_sa_month.csv?t=1765129851"

# %%
df = pd.read_csv(url)

df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2015-01-31  \
# 0      102001         0    United States    country       NaN    0.255645
# 1      394913         1     New York, NY        msa        NY    0.381005
# 2      753899         2  Los Angeles, CA        msa        CA    0.343744
# 3      394463         3      Chicago, IL        msa        IL    0.251807
# 4      394514         4       Dallas, TX        msa        TX    0.208415
# ..        ...       ...              ...        ...       ...         ...
# 387    394787       518     Lewiston, ID        msa        ID         NaN
# 388    394570       523         Enid, OK        msa        OK         NaN
# 389    395199       525  Walla Walla, WA        msa        WA         NaN
# 390    394444       551  Carson City, NV        msa        NV         NaN
# 391    394551       552   Eagle Pass, TX        msa        TX         NaN
#
#      2015-02-28  2015-03-31  2015-04-30  2015-05-31  ...  2025-01-31  \
# ...
